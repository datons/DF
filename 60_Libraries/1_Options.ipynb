# %% [markdown]
# # Python libraries for data science

# %% [markdown]
# [**See `libraries` instructions**](https://datons.craft.me/h3f5pSQSE7l6RW) to complete the following exercises.

# %% [markdown]
# ## Numerical operations: `numpy`
#
# https://numpy.org/doc/stable/reference/random/index.html

# %% [markdown]
# ## Graphs and plots: `plotly`
#
# https://plotly.com/python/plotly-express/

# %% [markdown]
# ### Line plot

# %% [markdown]
# ### Density contour plot

# %% [markdown]
# ### Maps

# %% [markdown]
# ### Scatter plot

# %% [markdown]
# ## Data tables: `pandas`
#
# https://pandas.pydata.org/docs/getting_started/

# %% [markdown]
# ### From scratch

# %%
# Out:
#             x          y
# 0   26.718645  34.648310
# 1   23.573563  26.493318
# ..        ...        ...
# 98  28.723011  32.754667
# 99  23.782762  29.349665
#
# [100 rows x 2 columns]

# %% [markdown]
# ### Excel

# %%
# Out:
#          Team  Games Played  Wins  Draws  Losses  Points Accumulated  \
# 0   Argentina             4     1      1       2                   4
# 1   Australia             3     0      1       2                   1
# ..        ...           ...   ...    ...     ...                 ...
# 30    Tunisia             3     1      0       2                   3
# 31    Uruguay             5     4      0       1                  12
#
#     Average Points per Game  Goals Scored  Average Goals per Game  \
# 0                      1.00             6                    1.50
# 1                      0.33             2                    0.67
# ..                      ...           ...                     ...
# 30                     1.00             5                    1.67
# 31                     2.40             7                    1.40
#
#     Goals Conceded  Average Goals Conceded per Game Goal Difference  \
# 0                9                             2.25              −3
# 1                5                             1.67              −3
# ..             ...                              ...             ...
# 30               8                             2.67              −3
# 31               3                             0.60              +4
#
#    Average Goal Difference  Clean Sheets  Average Clean Sheets  Yellow Cards  \
# 0                    −0.75             0                   0.0            11
# 1                    −1.00             0                   0.0             7
# ..                     ...           ...                   ...           ...
# 30                   −1.00             0                   0.0             4
# 31                    0.80             3                   0.6             3
#
#     Average Yellow Cards  Red Cards  Average Red Cards
# 0                   2.75          0                0.0
# 1                   2.33          0                0.0
# ..                   ...        ...                ...
# 30                  1.33          0                0.0
# 31                  0.60          0                0.0
#
# [32 rows x 19 columns]

# %% [markdown]
# ### CSV

# %%
# Out:
#   player  income  titles  grand slams  turned professional  wins  losses
# 0  roger     130     103           20                 1998  1251     275
# 1   rafa     127      90           21                 2001  1038     209
# 2   nole     154      86           20                 2003   989     199

# %% [markdown]
# ### HTML

# %%
# Out:
#     Position       Team  Team  Pl  Played  W  Won  D  Drawn  L  Lost  \
# 0          1        Barcelona          12      11         0        1
# 1          2      Real Madrid          11       7         3        1
# ..       ...              ...         ...     ...       ...      ...
# 18        19  Real Valladolid          12       2         2        8
# 19        20         Valencia          11       1         4        6
#
#     F  Goals For  A  Goals Against  GD  Goal Difference  Pts  Points
# 0             40                11                   29           33
# 1             21                11                   10           24
# ..           ...               ...                  ...          ...
# 18             9                24                  -15            8
# 19             8                17                   -9            7
#
# [20 rows x 10 columns]

# %% [markdown]
# ### Combine libraries

# %%
# Out:
#     Position             Team  Pl   W  D  L   F   A  GD  Pts
# 0          1        Barcelona  12  11  0  1  40  11  29   33
# 1          2      Real Madrid  11   7  3  1  21  11  10   24
# ..       ...              ...  ..  .. .. ..  ..  ..  ..  ...
# 18        19  Real Valladolid  12   2  2  8   9  24 -15    8
# 19        20         Valencia  11   1  4  6   8  17  -9    7
#
# [20 rows x 10 columns]

# %% [markdown]
# ## Machine Learning: `sklearn`
#
# https://scikit-learn.org/stable/user_guide.html

# %% [markdown]
# ### Linear regression

# %%
# Out:
# LinearRegression()

# %%
# Out:
#      F  Pts  Pts_pred_lr
# 0   40   33    35.445396
# 1   21   24    20.839319
# ..  ..  ...          ...
# 18   9    8    11.614429
# 19   8    7    10.845688
#
# [20 rows x 3 columns]

# %% [markdown]
# ### Decision Tree

# %%
# Out:
# DecisionTreeRegressor()

# %%
# Out:
#      F  Pts  Pts_pred_lr  Pts_pred_dt
# 0   40   33    35.445396         33.0
# 1   21   24    20.839319         24.0
# ..  ..  ...          ...          ...
# 18   9    8    11.614429          8.0
# 19   8    7    10.845688          8.5
#
# [20 rows x 4 columns]
