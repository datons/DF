# %% [markdown]
# # Optimal Data Visualization

# %% [markdown]
# ## Load dataset

# %%
# Out:
#          country continent  year  lifeExp       pop    gdpPercap iso_alpha  \
# 0    Afghanistan      Asia  2007   43.828  31889923   974.580338       AFG
# 1        Albania    Europe  2007   76.423   3600523  5937.029526       ALB
# ..           ...       ...   ...      ...       ...          ...       ...
# 140       Zambia    Africa  2007   42.384  11746035  1271.211593       ZMB
# 141     Zimbabwe    Africa  2007   43.487  12311143   469.709298       ZWE
#
#      iso_num
# 0          4
# 1          8
# ..       ...
# 140      894
# 141      716
#
# [142 rows x 8 columns]

# %% [markdown]
# ## Create data visualization

# %% [markdown]
# ### Import plotly library

# %% [markdown]
# ### Create scatter plot
#
# Represent the relationship between two **numerical** variables.

# %% [markdown]
# ### Change the color

# %% [markdown]
# **Exercise:** Based on the continent.

# %% [markdown]
# ---

# %% [markdown]
# ### Change the size

# %% [markdown]
# **Exercise:** Based on the population.

# %% [markdown]
# ### Show point name on hover

# %% [markdown]
# **Exercise:** Based on the country name.

# %% [markdown]
# ### Create multiple facets

# %% [markdown]
# **Exercise:** Based on the continent.

# %% [markdown]
# ## Data Analysis
#
# Based on visual observation, answer the following questions:

# %% [markdown]
# ### Which observation represents the biggest point?

# %% [markdown]
# - China

# %% [markdown]
# ### Which point is the furthest in the x-axis?

# %% [markdown]
# - Norway

# %% [markdown]
# ### Which point is the furthest in the y-axis?

# %% [markdown]
# - Japan

# %% [markdown]
# ---

# %% [markdown]
# ## Bonus: More data visualization
#
# See more interactive data visualization examples at:
#
# https://plotly.com/python/plotly-express/
#
# Copy paste the code and run it in your local environment.
